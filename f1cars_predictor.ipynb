# %% [markdown]
# # Predict f1car make using colab trained model

# %%
from fastai import *
from fastai.vision import *
import os

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#local dir '/Users/dexterdsilva/Documents/Developer/MachineLearning/fastai/course-v3/nbs/dl1/f1cars'
fdir=os.path.abspath('')
path = Path(fdir)

# %%
#loads export.pkl from dir
learn_inf=load_learner(path)

# %%
fimg = path/'test_images/f1cartest-13.jpeg'

# %%
img = open_image(fimg)

# %%
show_image(img)

# %%
preds, pred_idx, probs = learn_inf.predict(img)

# %%
print('Predict this is a {} with confidence {:.2f}%'.format(preds,
                                                          probs[pred_idx]*100))
# Out:
# Predict this is a racingpoint with confidence 99.93%
